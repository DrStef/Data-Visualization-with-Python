# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%204/logo.png" width="300" alt="cognitiveclass.ai logo" />
# </center>

# %% [markdown]
# # Assignment
#
# *   [Story](#story)
# *   [Components of the report items](#components-of-the-report-items)
# *   [Expected layout](#expected-layout)
# *   [Requirements to create the dashboard](#requirements-to-create-the-dashboard)
# *   [What is new in this exercise compared to other labs?](#what-is-new-in-this-exercise-compared-to-other-labs?)
# *   [Review](#review)
# *   [Hints to complete TODOs](#hints-to-complete-todos)
# *   [Application](#application)
#
# ## Story:
#
# As a data analyst, you have been given a task to monitor and report US domestic airline flights performance. Goal is to analyze the performance of the reporting airline to improve fight reliability thereby improving customer relaibility.
#
# Below are the key report items,
#
# *   Yearly airline performance report
# *   Yearly average flight delay statistics
#
# *NOTE:* Year range is between 2005 and 2020.
#
# ## Components of the report items
#
# 1.  Yearly airline performance report
#
#     For the chosen year provide,
#
#     *   Number of flights under different cancellation categories using bar chart.
#     *   Average flight time by reporting airline using line chart.
#     *   Percentage of diverted airport landings per reporting airline using pie chart.
#     *   Number of flights flying from each state using choropleth map.
#     *   Number of flights flying to each state from each reporting airline using treemap chart.
# 2.  Yearly average flight delay statistics
#
#     For the chosen year provide,
#
#     *   Monthly average carrier delay by reporting airline for the given year.
#     *   Monthly average weather delay by reporting airline for the given year.
#     *   Monthly average natioanl air system delay by reporting airline for the given year.
#     *   Monthly average security delay by reporting airline for the given year.
#     *   Monthly average late aircraft delay by reporting airline for the given year.
#
#     *NOTE:* You have worked created the same dashboard components in `Flight Delay Time Statistics Dashboard` section. We will be reusing the same.
#
# ## Expected Layout
#
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%205/images/Layout.png" width="2000" alt="cognitiveclass.ai logo"/>
# </center>

# %% [markdown]
# ## Requirements to create the dashboard
#
# *   Create dropdown using the reference [here](https://dash.plotly.com/dash-core-components/dropdown?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)
# *   Create two HTML divisions that can accomodate two components (in one division) side by side. One is HTML heading and the other one is dropdown.
# *   Add graph components.
# *   Callback function to compute data, create graph and return to the layout.

# %% [markdown]
# ## What's new in this exercise compared to other labs?
#
# *   Make sure the layout is clean without any defualt graphs or graph layouts. We will do this by 3 changes:
#
#     1.  Add `app.config.suppress_callback_exceptions = True` right after `app = JupyterDash(__name__)`.
#
#     2.  Having empty html.Div and use the callback to Output the dcc.graph as the Children of that Div.
#
#     3.  Add a state variable in addition to callback decorator input and output parameter. This will allow us to pass extra values without firing the callbacks.
#         Here, we need to pass two inputs `chart type` and `year`. Input is read only after user entering all the information.
#
# *   Use new html display style `flex` to arrange the dropdown menu with description.
#
# *   Update app run step to avoid getting error message before initiating callback.
#
# *NOTE:* These steps are only for review.

# %% [markdown]
# ## Review
#
# Search/Look for review to know how commands are used and computations are carried out. There are 7 review items.
#
# *   REVIEW1: Clear the layout and do not display exception till callback gets executed.
# *   REVIEW2: Dropdown creation.
# *   REVIEW3: Observe how we add an empty division and providing an id that will be updated during callback.
# *   REVIEW4: Holding output state till user enters all the form information. In this case, it will be chart type and year.
# *   REVIEW5: Number of flights flying from each state using choropleth
# *   REVIEW6: Return dcc.Graph component to the empty division
# *   REVIEW7: This covers chart type 2 and we have completed this exercise under Flight Delay Time Statistics Dashboard section
#
# ## Hints to complete TODOs
#
# ### TODO1
#
# Reference [link](https://dash.plotly.com/dash-html-components/h1?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)
#
# *   Provide title of the dash application title as `US Domestic Airline Flights Performance`.
# *   Make the heading center aligned, set color as `#503D36`, and font size as `24`.
#     Sample: style={'textAlign': 'left', 'color': '#000000', 'font-size': 0}
#
# ### TODO2
#
# Reference [link](https://dash.plotly.com/dash-core-components/dropdown?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)
#
# Create a dropdown menu and add two chart options to it.
#
# Parameters to be updated in `dcc.Dropdown`:
#
# *   Set `id` as `input-type`.
# *   Set `options` to list containing dictionaries with key as `label` and user provided value for labels in `value`.
#
#     *1st dictionary*
#
#     *   label: Yearly Airline Performance Report
#     *   value: OPT1
#
#     *2nd dictionary*
#
#     *   label: Yearly Airline Delay Report
#     *   value: OPT2
# *   Set placeholder to `Select a report type`.
# *   Set width as `80%`, padding as `3px`, font size as `20px`, text-align-last as `center` inside style parameter dictionary.
#
# #### Skeleton:
#
# ```
#   dcc.Dropdown(id='....',
#                    options=[
#                            {'label': '....', 'value': '...'},
#                            {'label': '....', 'value': '...'}
#                            ],
#                   placeholder='....',
#                   style={....})
# ```
#
# ### TODO3
#
# Add a division with two empty divisions inside. For reference, observe how code under `REVIEW` has been structured.
#
# Provide division ids as `plot4` and `plot5`. Display style as `flex`.
#
# #### Skeleton
#
# ```
# html.Div([
#          html.Div([ ], id='....'),
#          html.Div([ ], id='....')
#          ], style={....})
# ```
#
# ### TODO4
#
# Our layout has 5 outputs so we need to create 5 output components. Review how input components are constructured to fill in for output component.
#
# It is a list with 5 output parameters with component id and property. Here, the component property will be `children` as we have created empty division and passing in `dcc.Graph` after computation.
#
# Component ids will be `plot1` , `plot2`, `plot2`, `plot4`, and `plot5`.
#
# #### Skeleton
#
# ```
# [Output(component_id='plot1', component_property='children'),
#  Output(....),
#  Output(....),
#  Output(....),
#  Output(....)]
# ```
#
# ### TODO5
#
# Deals with creating line plots using returned dataframes from the above step using `plotly.express`. Link for reference is [here](https://plotly.com/python/line-charts/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)
#
# Average flight time by reporting airline
#
# *   Set figure name as `line_fig`, data as `line_data`, x as `Month`, y as `AirTime`, color as `Reporting_Airline` and `title` as `Average monthly flight time (minutes) by airline`.
#
# #### Skeleton
#
# ```
# carrier_fig = px.line(avg_car, x='Month', y='CarrierDelay', color='Reporting_Airline', title='Average carrrier delay time (minutes) by airline')`
# ```
#
# )
#
# ### TODO6
#
# Deals with creating treemap plot using returned dataframes from the above step using `plotly.express`. Link for reference is [here](https://plotly.com/python/treemaps/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)
#
# Number of flights flying to each state from each reporting airline
#
# *   Set figure name as `tree_fig`, data as `tree_data`, path as `['DestState', 'Reporting_Airline']`, values as `Flights`, colors as `Flights`, color_continuous_scale as `'RdBu'`, and title as `'Flight count by airline to destination state'`
#
# #### Skeleton
#
# ```
# tree_fig = px.treemap(data, path=['...', '...'],
#                       values='...',
#                       color='...',
#                       color_continuous_scale='...',
#                       title='...'
#                 )
# ```

# %%
# Out:
#   File "C:\Users\stefo\AppData\Local\Temp/ipykernel_20980/1235174390.py", line 2
#     .container {
#     ^
# SyntaxError: invalid syntax

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
#!pip install pandas dash
#!pip install sklearn
# !pip install pandas
# !pip install fairlearn
#!pip install bokeh
#!pip install matplotlib
# !pip install plotly
#!pip uninstall dash --y
#!pip install dash==2.1.0
#!pip install pandas dash
# !pip install jupyter-dash
# !pip install Flask==2.1.0
#!pip install environ
# Out:
# Requirement already satisfied: pandas in c:\users\stefo\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\stefo\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\stefo\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\stefo\anaconda3\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in c:\users\stefo\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: fairlearn in c:\users\stefo\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\stefo\anaconda3\lib\site-packages (from fairlearn) (1.20.3)
# Requirement already satisfied: pandas>=0.25.1 in c:\users\stefo\anaconda3\lib\site-packages (from fairlearn) (1.3.4)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\stefo\anaconda3\lib\site-packages (from fairlearn) (1.7.1)
# Requirement already satisfied: scikit-learn>=0.22.1 in c:\users\stefo\anaconda3\lib\site-packages (from fairlearn) (0.24.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\stefo\anaconda3\lib\site-packages (from pandas>=0.25.1->fairlearn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\stefo\anaconda3\lib\site-packages (from pandas>=0.25.1->fairlearn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\stefo\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->fairlearn) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\stefo\anaconda3\lib\site-packages (from scikit-learn>=0.22.1->fairlearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from scikit-learn>=0.22.1->fairlearn) (2.2.0)
# Requirement already satisfied: plotly in c:\users\stefo\anaconda3\lib\site-packages (5.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\stefo\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in c:\users\stefo\anaconda3\lib\site-packages (from plotly) (1.16.0)
# Requirement already satisfied: jupyter-dash in c:\users\stefo\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: requests in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-dash) (2.26.0)
# Requirement already satisfied: dash in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-dash) (2.1.0)
# Requirement already satisfied: ansi2html in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-dash) (1.7.0)
# Requirement already satisfied: retrying in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: ipykernel in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-dash) (6.4.1)
# Requirement already satisfied: ipython in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-dash) (7.29.0)
# Requirement already satisfied: flask in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-dash) (2.1.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: flask-compress in c:\users\stefo\anaconda3\lib\site-packages (from dash->jupyter-dash) (1.12)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from dash->jupyter-dash) (5.6.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\stefo\anaconda3\lib\site-packages (from flask->jupyter-dash) (3.1.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\stefo\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\stefo\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\stefo\anaconda3\lib\site-packages (from flask->jupyter-dash) (8.0.3)
# Requirement already satisfied: importlib-metadata in c:\users\stefo\anaconda3\lib\site-packages (from flask->jupyter-dash) (4.8.1)
# Requirement already satisfied: colorama in c:\users\stefo\anaconda3\lib\site-packages (from click>=8.0->flask->jupyter-dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\stefo\anaconda3\lib\site-packages (from Jinja2>=3.0->flask->jupyter-dash) (2.1.1)
# Requirement already satisfied: six in c:\users\stefo\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\stefo\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: brotli in c:\users\stefo\anaconda3\lib\site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\stefo\anaconda3\lib\site-packages (from importlib-metadata->flask->jupyter-dash) (3.6.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\stefo\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.1)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in c:\users\stefo\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.1.0)
# Requirement already satisfied: ipython-genutils in c:\users\stefo\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.2.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\stefo\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\stefo\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.1.12)
# Requirement already satisfied: pickleshare in c:\users\stefo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\stefo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (58.0.4)
# Requirement already satisfied: pygments in c:\users\stefo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\stefo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.18.0)
# Requirement already satisfied: decorator in c:\users\stefo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (5.1.0)
# Requirement already satisfied: backcall in c:\users\stefo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from ipython->jupyter-dash) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\stefo\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter-dash) (228)
# Requirement already satisfied: wcwidth in c:\users\stefo\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\stefo\anaconda3\lib\site-packages (from requests->jupyter-dash) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from requests->jupyter-dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\stefo\anaconda3\lib\site-packages (from requests->jupyter-dash) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stefo\anaconda3\lib\site-packages (from requests->jupyter-dash) (2021.10.8)
# Requirement already satisfied: Flask==2.1.0 in c:\users\stefo\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\stefo\anaconda3\lib\site-packages (from Flask==2.1.0) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\stefo\anaconda3\lib\site-packages (from Flask==2.1.0) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\stefo\anaconda3\lib\site-packages (from Flask==2.1.0) (8.0.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\stefo\anaconda3\lib\site-packages (from Flask==2.1.0) (3.1.1)
# Requirement already satisfied: importlib-metadata in c:\users\stefo\anaconda3\lib\site-packages (from Flask==2.1.0) (4.8.1)
# Requirement already satisfied: colorama in c:\users\stefo\anaconda3\lib\site-packages (from click>=8.0->Flask==2.1.0) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\stefo\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask==2.1.0) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\stefo\anaconda3\lib\site-packages (from importlib-metadata->Flask==2.1.0) (3.6.0)

# %%
# Import required libraries
import pandas as pd
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output, State
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update

# %%
#!pip install jupyter-server-proxy
# Out:
# Requirement already satisfied: jupyter-server-proxy in c:\users\stefo\anaconda3\lib\site-packages (1.0)
# Requirement already satisfied: aiohttp in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-server-proxy) (3.8.1)
# Requirement already satisfied: simpervisor>=0.2 in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-server-proxy) (0.3)
# Requirement already satisfied: notebook in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-server-proxy) (6.4.5)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\stefo\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\stefo\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (5.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\stefo\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\stefo\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (1.6.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\stefo\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (21.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\stefo\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (4.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\stefo\anaconda3\lib\site-packages (from aiohttp->jupyter-server-proxy) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\stefo\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp->jupyter-server-proxy) (3.10.0.2)
# Requirement already satisfied: idna>=2.0 in c:\users\stefo\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->jupyter-server-proxy) (3.2)
# Requirement already satisfied: argon2-cffi in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (20.1.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (6.1.12)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (4.8.1)
# Requirement already satisfied: jinja2 in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (3.1.1)
# Requirement already satisfied: nbformat in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (5.1.3)
# Requirement already satisfied: nbconvert in c:\users\stefo\appdata\roaming\python\python39\site-packages (from notebook->jupyter-server-proxy) (6.5.0)
# Requirement already satisfied: prometheus-client in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (0.11.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (22.2.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (6.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (1.8.0)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (5.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (0.9.4)
# Requirement already satisfied: ipython-genutils in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (0.2.0)
# Requirement already satisfied: ipykernel in c:\users\stefo\anaconda3\lib\site-packages (from notebook->jupyter-server-proxy) (6.4.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook->jupyter-server-proxy) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\stefo\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook->jupyter-server-proxy) (228)
# Requirement already satisfied: six>=1.5 in c:\users\stefo\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=5.3.4->notebook->jupyter-server-proxy) (1.16.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\stefo\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter-server-proxy) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter-server-proxy) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\stefo\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter-server-proxy) (2.20)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\stefo\anaconda3\lib\site-packages (from ipykernel->notebook->jupyter-server-proxy) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from ipykernel->notebook->jupyter-server-proxy) (1.4.1)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in c:\users\stefo\anaconda3\lib\site-packages (from ipykernel->notebook->jupyter-server-proxy) (7.29.0)
# Requirement already satisfied: colorama in c:\users\stefo\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->jupyter-server-proxy) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\stefo\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->jupyter-server-proxy) (0.7.5)
# Requirement already satisfied: pygments in c:\users\stefo\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->jupyter-server-proxy) (2.10.0)
# Requirement already satisfied: decorator in c:\users\stefo\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->jupyter-server-proxy) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->jupyter-server-proxy) (3.0.20)
# Requirement already satisfied: backcall in c:\users\stefo\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->jupyter-server-proxy) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\stefo\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->jupyter-server-proxy) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\stefo\anaconda3\lib\site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->jupyter-server-proxy) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\stefo\anaconda3\lib\site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->notebook->jupyter-server-proxy) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\stefo\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->notebook->jupyter-server-proxy) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\stefo\anaconda3\lib\site-packages (from jinja2->notebook->jupyter-server-proxy) (2.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\stefo\anaconda3\lib\site-packages (from nbconvert->notebook->jupyter-server-proxy) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\stefo\anaconda3\lib\site-packages (from nbconvert->notebook->jupyter-server-proxy) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\stefo\anaconda3\lib\site-packages (from nbconvert->notebook->jupyter-server-proxy) (0.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\stefo\anaconda3\lib\site-packages (from nbconvert->notebook->jupyter-server-proxy) (0.5.3)
# Requirement already satisfied: defusedxml in c:\users\stefo\anaconda3\lib\site-packages (from nbconvert->notebook->jupyter-server-proxy) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\stefo\anaconda3\lib\site-packages (from nbconvert->notebook->jupyter-server-proxy) (4.10.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\stefo\anaconda3\lib\site-packages (from nbconvert->notebook->jupyter-server-proxy) (0.8.4)
# Requirement already satisfied: packaging in c:\users\stefo\anaconda3\lib\site-packages (from nbconvert->notebook->jupyter-server-proxy) (21.0)
# Requirement already satisfied: tinycss2 in c:\users\stefo\appdata\roaming\python\python39\site-packages (from nbconvert->notebook->jupyter-server-proxy) (1.1.1)
# Requirement already satisfied: bleach in c:\users\stefo\anaconda3\lib\site-packages (from nbconvert->notebook->jupyter-server-proxy) (4.0.0)
# Requirement already satisfied: async-generator in c:\users\stefo\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert->notebook->jupyter-server-proxy) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\stefo\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert->notebook->jupyter-server-proxy) (1.5.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\stefo\anaconda3\lib\site-packages (from nbformat->notebook->jupyter-server-proxy) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\stefo\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter-server-proxy) (0.18.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\stefo\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook->jupyter-server-proxy) (2.2.1)
# Requirement already satisfied: webencodings in c:\users\stefo\anaconda3\lib\site-packages (from bleach->nbconvert->notebook->jupyter-server-proxy) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\stefo\anaconda3\lib\site-packages (from packaging->nbconvert->notebook->jupyter-server-proxy) (3.0.4)

# %%
# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})

# %%
airline_data.head()
# Out:
#    Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0     1295781  1998        2      4           2          4  1998-04-02
# 1     1125375  2013        2      5          13          1  2013-05-13
# 2      118824  1993        3      9          25          6  1993-09-25
# 3      634825  1994        4     11          12          6  1994-11-12
# 4     1888125  2017        3      8          17          4  2017-08-17
#
#   Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                AS                     19930                          AS
# 1                EV                     20366                          EV
# 2                UA                     19977                          UA
# 3                HP                     19991                          HP
# 4                UA                     19977                          UA
#
#    ... Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# 0  ...           NaN          NaN          NaN            NaN
# 1  ...           NaN          NaN          NaN            NaN
# 2  ...           NaN          NaN          NaN            NaN
# 3  ...           NaN          NaN          NaN            NaN
# 4  ...           NaN          NaN          NaN            NaN
#
#    Div5AirportSeqID Div5WheelsOn Div5TotalGTime Div5LongestGTime  \
# 0               NaN          NaN            NaN              NaN
# 1               NaN          NaN            NaN              NaN
# 2               NaN          NaN            NaN              NaN
# 3               NaN          NaN            NaN              NaN
# 4               NaN          NaN            NaN              NaN
#
#    Div5WheelsOff Div5TailNum
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
#
# [5 rows x 110 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13100/209845007.py in <module>
# ----> 1 del app.config._read_only["requests_pathname_prefix"]
#
# NameError: name 'app' is not defined

# %%
from jupyter_dash.comms import _send_jupyter_config_comm_request
_send_jupyter_config_comm_request()

# %%
from jupyter_dash import JupyterDash
#[other dash imports]

# %% [markdown]
# ## Application

# %%
# Create a dash application
app = JupyterDash(__name__)
JupyterDash.infer_jupyter_proxy_config()

# REVIEW1: Clear the layout and do not display exception till callback gets executed
app.config.suppress_callback_exceptions = True
del app.config._read_only["requests_pathname_prefix"]
# List of years 
year_list = [i for i in range(2005, 2021, 1)]

"""Compute graph data for creating yearly airline performance report 

Function that takes airline data as input and create 5 dataframes based on the grouping condition to be used for plottling charts and grphs.

Argument:
     
    df: Filtered dataframe
    
Returns:
   Dataframes to create graph. 
"""
def compute_data_choice_1(df):
    # Cancellation Category Count
    bar_data = df.groupby(['Month','CancellationCode'])['Flights'].sum().reset_index()
    # Average flight time by reporting airline
    line_data = df.groupby(['Month','Reporting_Airline'])['AirTime'].mean().reset_index()
    # Diverted Airport Landings
    div_data = df[df['DivAirportLandings'] != 0.0]
    # Source state count
    map_data = df.groupby(['OriginState'])['Flights'].sum().reset_index()
    # Destination state count
    tree_data = df.groupby(['DestState', 'Reporting_Airline'])['Flights'].sum().reset_index()
    return bar_data, line_data, div_data, map_data, tree_data


"""Compute graph data for creating yearly airline delay report

This function takes in airline data and selected year as an input and performs computation for creating charts and plots.

Arguments:
    df: Input airline data.
    
Returns:
    Computed average dataframes for carrier delay, weather delay, NAS delay, security delay, and late aircraft delay.
"""
def compute_data_choice_2(df):
    # Compute delay averages
    avg_car = df.groupby(['Month','Reporting_Airline'])['CarrierDelay'].mean().reset_index()
    avg_weather = df.groupby(['Month','Reporting_Airline'])['WeatherDelay'].mean().reset_index()
    avg_NAS = df.groupby(['Month','Reporting_Airline'])['NASDelay'].mean().reset_index()
    avg_sec = df.groupby(['Month','Reporting_Airline'])['SecurityDelay'].mean().reset_index()
    avg_late = df.groupby(['Month','Reporting_Airline'])['LateAircraftDelay'].mean().reset_index()
    return avg_car, avg_weather, avg_NAS, avg_sec, avg_late


# Application layout
                                # TODO1: Add title to the dashboard - X
    # Provide title of the dash application title as US Domestic Airline Flights Performance.
    # Make the heading center aligned, set color as #503D36, 
    # and font size as 24. Sample: style={'textAlign': 'left', 'color': '#000000', 'font-size': 0}

app.layout = html.Div(children=[html.H1('US Domestic Airline Flights Performance', 
                                style={'textAlign':'center', 
                                'color':'#503D36', 
                                'font-size': 24}), 

                                # REVIEW2: Dropdown creation
                                # Create an outer division 
                                html.Div([
                                    # Add an division
                                    html.Div([
                                        # Create an division for adding dropdown helper text for report type
                                        html.Div(
                                            [
                                            html.H2('Report Type:', style={'margin-right': '2em'}),
                                            ]
                                        ),
                                        # TODO2: Add a dropdown
    #Create a dropdown menu and add two chart options to it.
    #Parameters to be updated in dcc.Dropdown:
    #Set id as input-type.
    #Set options to list containing dictionaries with key as label and user provided value for labels in value.
    #1st dictionary
    #    label: Yearly Airline Performance Report
    #    value: OPT1
    #2nd dictionary
    #    label: Yearly Airline Delay Report
    #    value: OPT2
    #Set placeholder to Select a report type.
    #Set width as 80%, padding as 3px, font size as 20px, text-align-last as center inside style parameter dictionary.        
                                # Place them next to each other using the division style
                                dcc.Dropdown(id='input-type', 
                                        options=[{'label': 'Yearly Airline Performance Report', 'value': 'OPT1'},
                                                 {'label': 'Yearly Airline Delay Report', 'value': 'OPT2'}],
                                                placeholder='Select a Report',
                                                style={'width':'80%', 
                                                       'padding':'3px',
                                                       'font-size': '20px', 
                                                       'text-align-last' : 'center'}),                                           
                                    ], style={'display':'flex'}),
                                    
                                   # Add next division 
                                   html.Div([
                                       # Create an division for adding dropdown helper text for choosing year
                                        html.Div(
                                            [
                                            html.H2('Choose Year:', style={'margin-right': '2em'})
                                            ]
                                        ),
                                        dcc.Dropdown(id='input-year', 
                                                     # Update dropdown values using list comphrehension
                                                     options=[{'label': i, 'value': i} for i in year_list],
                                                     placeholder="Select a year",
                                                     style={'width':'80%', 'padding':'3px', 'font-size': '20px', 'text-align-last' : 'center'}),
                                            # Place them next to each other using the division style
                                            ], style={'display': 'flex'}),  
                                          ]),
                                
                                # Add Computed graphs
                                # REVIEW3: Observe how we add an empty division and providing an id that will be updated during callback
                                html.Div([ ], id='plot1'),
    
                                html.Div([
                                        html.Div([ ], id='plot2'),
                                        html.Div([ ], id='plot3')
                                ], style={'display': 'flex'}),
                                
                                # TODO3: Add a division with two empty divisions inside. See above disvision for example.
                                # Provide division ids as plot4 and plot5. Display style as flex.
                                 html.Div([
                                        html.Div([ ], id='plot4'),
                                        html.Div([ ], id='plot5')
                                ], style={'display': 'flex'}),                               
                                ])

# Callback function definition
# TODO4: Add 5 ouput components
# Our layout has 5 outputs so we need to create 5 output components. Review how input components are constructured to fill in for output component.
# It is a list with 5 output parameters with component id and property. Here, the component property will be children as we have created empty division and passing in dcc.Graph after computation.
# Component ids will be plot1 , plot2, plot2, plot4, and plot5.


@app.callback([ Output(component_id='plot1', component_property='children'),
                Output(component_id='plot2', component_property='children'),
                Output(component_id='plot3', component_property='children'),
                Output(component_id='plot4', component_property='children'),
                Output(component_id='plot5', component_property='children')],
               [Input(component_id='input-type', component_property='value'),
                Input(component_id='input-year', component_property='value')],
               # REVIEW4: Holding output state till user enters all the form information. In this case, it will be chart type and year
               [State("plot1", 'children'), State("plot2", "children"),
                State("plot3", "children"), State("plot4", "children"),
                State("plot5", "children")
               ])
# Add computation to callback function and return graph
def get_graph(chart, year, children1, children2, c3, c4, c5):
      
        # Select data
        df =  airline_data[airline_data['Year']==int(year)]
       
        if chart == 'OPT1':
            # Compute required information for creating graph from the data
            bar_data, line_data, div_data, map_data, tree_data = compute_data_choice_1(df)
            
            # Number of flights under different cancellation categories
            bar_fig = px.bar(bar_data, x='Month', y='Flights', color='CancellationCode', title='Monthly Flight Cancellation')
            
            # TODO5: Average flight time by reporting airline
            # Deals with creating line plots using returned dataframes from the above step using plotly.express. Link for reference is here
            # Average flight time by reporting airline
            # Set figure name as line_fig, data as line_data, x as Month, y as AirTime, 
            # color as Reporting_Airline and title as Average monthly flight time (minutes) by airline.
            #  carrier_fig = px.line(avg_car, x='Month', y='CarrierDelay', color='Reporting_Airline', title='Average carrrier delay time (minutes) by airline')`
                        # Enter your code below. Make sure you have correct formatting.
            line_fig = px.line(line_data, x='Month', y='AirTime', color='Reporting_Airline', title='Average monthly flight time (minutes) by airline')
             
            # Percentage of diverted airport landings per reporting airline
            pie_fig = px.pie(div_data, values='Flights', names='Reporting_Airline', title='% of flights by reporting airline')
            
            # REVIEW5: Number of flights flying from each state using choropleth
            map_fig = px.choropleth(map_data,  # Input data
                    locations='OriginState', 
                    color='Flights',  
                    hover_data=['OriginState', 'Flights'], 
                    locationmode = 'USA-states', # Set to plot as US States
                    color_continuous_scale='GnBu',
                    range_color=[0, map_data['Flights'].max()]) 
            map_fig.update_layout(
                    title_text = 'Number of flights from origin state', 
                    geo_scope='usa') # Plot only the USA instead of globe
            
            # TODO6: Number of flights flying to each state from each reporting airline
            # Deals with creating treemap plot using returned dataframes from the above step using plotly.express. Link for reference is here
            # Number of flights flying to each state from each reporting airline
            # Set figure name as tree_fig, data as tree_data, path as ['DestState', 'Reporting_Airline'], values as Flights, colors as Flights, color_continuous_scale as 'RdBu', and title as 'Flight count by airline to destination state'
            tree_fig = px.treemap(tree_data, 
                        path=['DestState', 'Reporting_Airline'], 
                        values= 'Flights', 
                        color='Flights', 
                        color_continuous_scale='RdBu',
                        title='Flight count by airline to destination state')

            
            # REVIEW6: Return dcc.Graph component to the empty division
            return [dcc.Graph(figure=tree_fig), 
                    dcc.Graph(figure=pie_fig),
                    dcc.Graph(figure=map_fig),
                    dcc.Graph(figure=bar_fig),
                    dcc.Graph(figure=line_fig)
                   ]
        else:
            # REVIEW7: This covers chart type 2 and we have completed this exercise under Flight Delay Time Statistics Dashboard section
            # Compute required information for creating graph from the data
            avg_car, avg_weather, avg_NAS, avg_sec, avg_late = compute_data_choice_2(df)
            
            # Create graph
            carrier_fig = px.line(avg_car, x='Month', y='CarrierDelay', color='Reporting_Airline', title='Average carrrier delay time (minutes) by airline')
            weather_fig = px.line(avg_weather, x='Month', y='WeatherDelay', color='Reporting_Airline', title='Average weather delay time (minutes) by airline')
            nas_fig = px.line(avg_NAS, x='Month', y='NASDelay', color='Reporting_Airline', title='Average NAS delay time (minutes) by airline')
            sec_fig = px.line(avg_sec, x='Month', y='SecurityDelay', color='Reporting_Airline', title='Average security delay time (minutes) by airline')
            late_fig = px.line(avg_late, x='Month', y='LateAircraftDelay', color='Reporting_Airline', title='Average late aircraft delay time (minutes) by airline')
            
            return[dcc.Graph(figure=carrier_fig), 
                   dcc.Graph(figure=weather_fig), 
                   dcc.Graph(figure=nas_fig), 
                   dcc.Graph(figure=sec_fig), 
                   dcc.Graph(figure=late_fig)]


# Run the app
if __name__ == '__main__':
    #app.run_server(mode='inline')
    #app.run_server()
    # REVIEW8: Adding dev_tools_ui=False, dev_tools_props_check=False can prevent error appearing before calling callback function
    app.run_server(mode="inline", host="localhost", debug=False, dev_tools_ui=False, dev_tools_props_check=False)
    
    #app.run_server(mode='jupyterlab')
    #app.run_server(mode='external',port=8050)
    #app.run_server(mode="external")
    #app.run_server(debug=True)
# Out:
#  * Running on http://localhost:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [11/May/2022 21:11:13] "GET /_alive_d95509ab-eda9-41dc-8db8-4569c100059b HTTP/1.1" 200 -
#         <iframe
#             width="100%"
#             height="650"
#             src="http://localhost:8889/proxy/8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# !pip install  watermark
# Out:
# Requirement already satisfied: watermark in c:\users\stefo\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: ipython in c:\users\stefo\anaconda3\lib\site-packages (from watermark) (7.29.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\stefo\anaconda3\lib\site-packages (from ipython->watermark) (58.0.4)
# Requirement already satisfied: colorama in c:\users\stefo\anaconda3\lib\site-packages (from ipython->watermark) (0.4.4)
# Requirement already satisfied: decorator in c:\users\stefo\anaconda3\lib\site-packages (from ipython->watermark) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\stefo\anaconda3\lib\site-packages (from ipython->watermark) (0.7.5)
# Requirement already satisfied: pygments in c:\users\stefo\anaconda3\lib\site-packages (from ipython->watermark) (2.10.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\stefo\anaconda3\lib\site-packages (from ipython->watermark) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\stefo\anaconda3\lib\site-packages (from ipython->watermark) (0.18.0)
# Requirement already satisfied: backcall in c:\users\stefo\anaconda3\lib\site-packages (from ipython->watermark) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\stefo\anaconda3\lib\site-packages (from ipython->watermark) (5.1.0)
# Requirement already satisfied: matplotlib-inline in c:\users\stefo\anaconda3\lib\site-packages (from ipython->watermark) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\stefo\anaconda3\lib\site-packages (from jedi>=0.16->ipython->watermark) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\stefo\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->watermark) (0.2.5)

# %%
# %reload_ext watermark

# python, ipython, packages, and machine characteristics
#%watermark -v -m -p wget,pandas,numpy,altair
# %watermark --iversions
# date
print (" ")
# %watermark -u -n -t -z
# Out:
# plotly: 5.6.0
# pandas: 1.3.4
# dash  : 2.1.0
#
#
# Last updated: Wed May 11 2022 21:21:46Eastern Daylight Time

# %% [markdown]
# ## Summary
#
# Congratulations for completing your dash and plotly assignment.
#
# More information about the libraries can be found [here](https://dash.plotly.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)

# %% [markdown]
# ## Author
#
# [Saishruthi Swaminathan](https://www.linkedin.com/in/saishruthi-swaminathan/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01)

# %% [markdown]
# ## Changelog
#
# | Date       | Version | Changed by | Change Description                   |
# | ---------- | ------- | ---------- | ------------------------------------ |
# | 12-18-2020 | 1.0     | Nayef      | Added dataset link and upload to Git |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
